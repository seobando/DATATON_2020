# %% [markdown]
# # ENTENDIMIENTO DE LOS DATOS

# %% [markdown]
# El presente notebook busca analizar la incompletitud de los datos con el objetivo de seleccionar variables tentativas a ser eliminadas o que requieren un mayor tratamiento en caso de que desde la definición de negocio sean relevantes.

# %% [markdown]
# ## SET UP

# %%
# !pip install findspark

import findspark
findspark.init()
# Out:
# Requirement already satisfied: findspark in c:\users\sobando\anaconda3\lib\site-packages (1.3.0)

# %% [markdown]
# ## LIBRERIAS

# %%
# Cargar Pyspark
from pyspark.sql import SparkSession
from pyspark import SparkContext
from pyspark import SparkConf
from pyspark.sql.functions import *

spark = SparkSession.builder.appName("Test_spark").master("local[*]").getOrCreate()

# %%
from pyspark.sql.functions import *
from pyspark.sql import Window
from pyspark.sql.types import *

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## ANÁLISIS EXPLORATORIO

# %%
header = spark.read.text("input/header.txt").collect()[0][:][0].split(",")

# %%
# Getting summary of groups and frequencies
# Initialize empty dataframe 
collector = pd.DataFrame([["start","start",0,0.0]], columns = ["variable","categoria","frecuencia_absoluta","frecuencia_relativa"])
# Initialize missing variables
missing = []
# Get the path
for var in header:
    try:
        #
        path = "output/" + var + ".csv"
        df = spark.read.option("header",True).csv(path)
        df = df.where(col("categoria") == "\\N")
        #
        if df.count() != 0:
            # 
            new_row = df.select("variable","categoria","frecuencia_absoluta","frecuencia_relativa").toPandas()
            # Apend rows
            collector = collector.append(new_row)
    except:
        # Getting missing variables
        missing.append(var)
        pass

# %%
# Missing Variables
print(missing)
# Out:
# ['ind', 'gasto_familiar']

# %%
# Cleaning incomplete dataframe
incomplete = (collector
              .set_index("variable")
              .drop(["start"],axis=0)
              .sort_values(by="frecuencia_relativa",ascending=False)
              .reset_index())

# %%
# Setting max number of rows to display in a dataframe
pd.set_option('display.max_rows', None)
display(incomplete)
# Out:
#                          variable categoria frecuencia_absoluta  \
# 0                 nro_tot_cuentas        \N                 228
# 1                 ctas_embargadas        \N                 228
# 2                    ctas_activas        \N                 228
# 3           tiene_ctas_embargadas        \N            20929152
# 4                 rechazo_credito        \N            20874444
# 5                   pension_fopep        \N            20546842
# 6               tiene_cred_hipo_2        \N            19355492
# 7               tiene_cred_hipo_1        \N            19355492
# 8                cuota_cred_hipot        \N            19355492
# 9                   tiene_consumo        \N            18315025
# 10                tiene_crediagil        \N            18116033
# 11                   convenio_lib        \N            17942961
# 12                 ingreso_nomina        \N            15472674
# 13        ingreso_segurida_social        \N            15154004
# 14                    cat_ingreso        \N            12676813
# 15                  tipo_vivienda        \N            10014484
# 16                      profesion        \N             6152365
# 17     cant_moras_30_ult_12_meses        \N             5971628
# 18     cant_moras_90_ult_12_meses        \N             5971628
# 19                       mora_max        \N             5971628
# 20     cant_moras_60_ult_12_meses        \N             5971628
# 21           departamento_laboral        \N             5639198
# 22                 ciudad_laboral        \N             5478163
# 23           cant_cast_ult_12m_sr        \N             3383364
# 24              cant_oblig_tot_sf        \N             3383364
# 25     cant_mora_30_tdc_ult_3m_sf        \N             3262883
# 26  cant_mora_30_consum_ult_3m_sf        \N             3262883
# 27                  pol_centr_ext        \N             3069445
# 28             tiene_ctas_activas        \N             1370611
# 29                      categoria        \N              222045
# 30                  ingreso_final        \N              154051
# 31                   estado_civil        \N               94744
# 32              ciudad_residencia        \N               49752
# 33               ind_mora_vigente        \N               14490
# 34              cartera_castigada        \N               14490
# 35        departamento_residencia        \N               11471
# 36                      ocupacion        \N                9456
# 37                           edad        \N                5018
#
#        frecuencia_relativa
# 0    1.086296333635527e-05
# 1    1.086296333635527e-05
# 2    1.086296333635527e-05
# 3         0.99716057384652
# 4       0.9945540343807072
# 5         0.97894557598195
# 6       0.9221842103206919
# 7       0.9221842103206919
# 8       0.9221842103206919
# 9       0.8726116012255709
# 10      0.8631307117508867
# 11      0.8548847696870723
# 12      0.7371889928832344
# 13      0.7220060958376364
# 14      0.6039813808808415
# 15       0.477135844405774
# 16      0.2931268220476991
# 17     0.28451568430856383
# 18     0.28451568430856383
# 19     0.28451568430856383
# 20     0.28451568430856383
# 21      0.2686771978967016
# 22      0.2610047535946403
# 23     0.16119894335765048
# 24     0.16119894335765048
# 25     0.15545867719217935
# 26     0.15545867719217935
# 27     0.14624240569280264
# 28     0.06530218000616331
# 29    0.010579239886057043
# 30    0.007339694583021341
# 31    0.004514037712015981
# 32    0.002370412946975208
# 33   0.0006903699067709994
# 34   0.0006903699067709994
# 35   0.0005465309317163653
# 36  0.00045052711100252384
# 37  0.00023908048255188923

# %% [markdown]
# ## Seleccionar variables a eliminar:

# %%
drop_variables =incomplete.astype({"variable":'category',"categoria":'category', "frecuencia_absoluta":'int64', "frecuencia_relativa":'float64'}) 
drop_variables = drop_variables[drop_variables["frecuencia_relativa"] >= 0.7]
lista = drop_variables["variable"].tolist()
print(lista)
# Out:
# ['tiene_ctas_embargadas', 'rechazo_credito', 'pension_fopep', 'tiene_cred_hipo_2', 'tiene_cred_hipo_1', 'cuota_cred_hipot', 'tiene_consumo', 'tiene_crediagil', 'convenio_lib', 'ingreso_nomina', 'ingreso_segurida_social']

# %%
pd.set_option('display.max_rows', None)
display(drop_variables)
# Out:
#                    variable categoria  frecuencia_absoluta  \
# 3     tiene_ctas_embargadas        \N             20929152
# 4           rechazo_credito        \N             20874444
# 5             pension_fopep        \N             20546842
# 6         tiene_cred_hipo_2        \N             19355492
# 7         tiene_cred_hipo_1        \N             19355492
# 8          cuota_cred_hipot        \N             19355492
# 9             tiene_consumo        \N             18315025
# 10          tiene_crediagil        \N             18116033
# 11             convenio_lib        \N             17942961
# 12           ingreso_nomina        \N             15472674
# 13  ingreso_segurida_social        \N             15154004
#
#     frecuencia_relativa
# 3              0.997161
# 4              0.994554
# 5              0.978946
# 6              0.922184
# 7              0.922184
# 8              0.922184
# 9              0.872612
# 10             0.863131
# 11             0.854885
# 12             0.737189
# 13             0.722006

# %%
len(lista)
# Out:
# 11
